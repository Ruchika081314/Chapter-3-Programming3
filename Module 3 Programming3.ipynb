# %% [markdown]
# # Chapter 7 and Chapter 9 Programming Assignment
# This notebook contains the solutions for sections 7.4, 7.5, 7.6, 9.1, and 9.2.

# %%
# 7.4
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
# 7.5
things[1] = things[1].capitalize()
print(things)

# Yes, the element in the list changed.
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# ### Answer:
# Yes, capitalizing the string changed the element in the list.

# %%
# 7.6
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
# 9.1
def good():
    return ['Harry', 'Ron', 'Hermione']

print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
# 9.2
def get_odds():
    for number in range(10):
        if number % 2 != 0:
            yield number

count = 0
for value in get_odds():
    count += 1
    if count == 3:
        print(value)
        break
# Out:
# 5

# %%
# 7.7
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']
